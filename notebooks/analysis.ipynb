# %%
import pandas as pd
import numpy as np
import sklearn as skl

# %%
df = pd.read_csv("../data/Players.csv")
print((df.head()))
df.shape
# Out:
#    season   lg            player  player_id   age team pos   g    gs     mp  \
# 0    2026  NBA  Precious Achiuwa  achiupr01  26.0  SAC   C  26  13.0  516.0
# 1    2026  NBA      Steven Adams  adamsst01  32.0  HOU   C  25   7.0  542.0
# 2    2026  NBA       Bam Adebayo  adebaba01  28.0  MIA   C  25  25.0  774.0
# 3    2026  NBA      Ochai Agbaji  agbajoc01  25.0  TOR  SG  27  11.0  452.0
# 4    2026  NBA      Santi Aldama  aldamsa01  25.0  MEM  PF  33   8.0  922.0
#
#    ...  tov_percent  usg_percent  ows  dws   ws  ws_48  obpm  dbpm  bpm  vorp
# 0  ...          5.8         15.5  0.4  0.4  0.8  0.072  -1.4  -0.7 -2.2   0.0
# 1  ...         16.4         12.6  0.9  0.7  1.7  0.148   0.4  -0.5 -0.1   0.3
# 2  ...         10.6         23.4  0.4  1.4  1.7  0.108   0.1   1.1  1.2   0.6
# 3  ...          5.9         12.7  0.1  0.5  0.6  0.062  -4.7   0.2 -4.5  -0.3
# 4  ...          9.8         20.5  0.9  1.3  2.2  0.114   1.1   0.9  2.0   0.9
#
# [5 rows x 30 columns]
# (33119, 30)
